# %%
import pandas as pd
import math
import numpy as np
import random
import matplotlib.pyplot as plt
#import seaborn as sb
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
# %matplotlib inline
pd.options.display.max_rows = 10
plt.style.use('fivethirtyeight')

# %%
df0 = pd.DataFrame.from_csv('facebooknaive.csv',header=0,index_col=None); df0.head()
# Out:
#    metacritic  bias  actors_likes  director_likes  writer_likes  movie_likes
# 0   11.312406   1.0      0.540625        2.396735      2.177129     5.830888
# 1   10.654445   1.0      1.775080        2.632449      2.391246     2.705245
# 2   11.051242   1.0      0.491731        2.393839      0.000000     5.821847
# 3    9.251031   1.0      0.374191        0.000000      0.000000     3.946647
# 4   10.759683   1.0      2.129763        0.516924      0.469560     4.288445

# %%
df1 = pd.DataFrame.from_csv('facebook.csv',header=0,index_col=None); df1.head()
# Out:
#    metacritic  bias  actors_likes  director_likes  writer_likes  movie_likes
# 0   11.753275   1.0      0.534921        2.542807      2.068782     7.275998
# 1   11.751300   1.0      2.104764        2.465665      2.296811     3.751087
# 2   11.481932   1.0      0.462073        2.539735      0.000000     7.264716
# 3    9.611564   1.0      0.354804        0.000000      0.000000     4.924773
# 4   12.262316   1.0      2.375781        0.500139      0.484480     5.440450

# %%
df2 = pd.DataFrame.from_csv('facebook_awd.csv',header=0,index_col=None); df2.head()
# Out:
#    metacritic  bias  actors_likes  director_likes  writer_likes  movie_likes  \
# 0   11.753275   1.0      0.534921        2.542807      2.068782     7.275998
# 1   11.751300   1.0      2.104764        2.465665      2.296811     3.751087
# 2   11.481932   1.0      0.462073        2.539735      0.000000     7.264716
# 3    9.611564   1.0      0.354804        0.000000      0.000000     4.924773
# 4   12.262316   1.0      2.375781        0.500139      0.484480     5.440450
#
#    actors_awards  director_awards  writer_awards
# 0        0.58140         2.741758       2.505667
# 1        1.39919         1.612615       1.457766
# 2        0.00000         2.189215       0.000000
# 3        0.00000         0.000000       0.000000
# 4        4.39284         0.936926       0.940264

# %% [markdown]
# # Facebook-only Model (naive)

# %%
y = df0.iloc[:,0]
X = df0.iloc[:,1:]

# %% [markdown]
# Split the dataset, then set aside the test set for later...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Cross-Validation:

# %%
model = RidgeCV(alphas=(10,25,50,75,100), fit_intercept = True, cv = 10)
fit = model.fit(X_train,y_train)

# %% [markdown]
# Score our cross-validated model on the test set

# %%
y_pred = fit.predict(X_test)
score = metrics.r2_score(y_test, y_pred)
S1 = score

res = fit.predict(X)-y

fig = plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter(X.iloc[:,1], res,alpha = .3)
plt.plot(X_test.iloc[:,1],X_test.iloc[:,1]*0,alpha = .5)
plt.xlabel('first feature variable')
plt.ylabel('residual')
plt.xlim([0.5,5.8])
plt.title('residual plot ' + ' (r-squared = ' + str(score) +')');

plt.subplot(1,2,2)
plt.hist(res,bins = 50,alpha = .5)
plt.xlabel('residual')
plt.ylabel('count')
plt.xlim([-6,6])
plt.title('residual histogram');
import plotly.plotly as py
import plotly.tools as tls
plotly_fig = tls.mpl_to_plotly(fig)
py.iplot(plotly_fig)
# Out:
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/renderer.py:516: UserWarning:
#
# Looks like the annotation(s) you are trying
# to draw lies/lay outside the given figure size.
#
# Therefore, the resulting Plotly figure may not be
# large enough to view the full text. To adjust
# the size of the figure, use the 'width' and
# 'height' keys in the Layout object. Alternatively,
# use the Margin object to adjust the figure's margins.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bobtian/19.embed" height="360px" width="1080px"></iframe>

# %% [markdown]
# # Facebook-only Model (grouped)

# %%
y = df1.iloc[:,0]
X = df1.iloc[:,1:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = RidgeCV(alphas=(10,25,50,75,100), fit_intercept = True, cv = 10)
fit = model.fit(X_train,y_train)
y_pred = fit.predict(X_test)
score = metrics.r2_score(y_test, y_pred)

res2 = fit.predict(X)-y
fig = plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter(X.iloc[:,1], res2,alpha = .3, c='b')
plt.plot(X_test.iloc[:,1],X_test.iloc[:,1]*0,c='k',alpha = .5)
plt.xlabel('first feature variable')
plt.ylabel('residual')
plt.xlim([0.5,7.5])
plt.title('residual plot ' + ' (r-squared = ' + str(score) +')');

plt.subplot(1,2,2)
plt.hist(res2,bins = 50,alpha = .5,color='b')
plt.xlabel('residual')
plt.ylabel('count')
plt.xlim([-6,6])
plt.title('residual histogram');
plt.legend(['Naive Model','Group-Standardized Model']);

# %%
import plotly.plotly as py
import plotly.tools as tls
plotly_fig = tls.mpl_to_plotly(fig)
py.iplot(plotly_fig)
# Out:
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/renderer.py:516: UserWarning:
#
# Looks like the annotation(s) you are trying
# to draw lies/lay outside the given figure size.
#
# Therefore, the resulting Plotly figure may not be
# large enough to view the full text. To adjust
# the size of the figure, use the 'width' and
# 'height' keys in the Layout object. Alternatively,
# use the Margin object to adjust the figure's margins.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-79fcc6e11062> in <module>()
#       1 import plotly.plotly as py
#       2 import plotly.tools as tls
# ----> 3 plotly_fig = tls.mpl_to_plotly(fig)
#       4 py.iplot(plotly_fig)
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     508     if _matplotlylib_imported:
#     509         renderer = matplotlylib.PlotlyRenderer()
# --> 510         matplotlylib.Exporter(renderer).run(fig)
#     511         if resize:
#     512             renderer.resize()
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      47             import matplotlib.pyplot as plt
#      48             plt.close(fig)
# ---> 49         self.crawl_fig(fig)
#      50
#      51     @staticmethod
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
# --> 116                 self.crawl_ax(ax)
#     117
#     118     def crawl_ax(self, ax):
#
# /Users/Bob/anaconda/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_figure(self, fig, props)
#      42         self._fig_props = props
#      43         self.open_figure(fig=fig, props=props)
# ---> 44         yield
#      45         self.close_figure(fig=fig)
#      46         self._current_fig = None
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
# --> 116                 self.crawl_ax(ax)
#     117
#     118     def crawl_ax(self, ax):
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_ax(self, ax)
#     145                 with self.renderer.draw_legend(legend=legend, props=props):
#     146                     if props['visible']:
# --> 147                         self.crawl_legend(ax, legend)
#     148
#     149     def crawl_legend(self, ax, legend):
#
# /Users/Bob/anaconda/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_axes(self, ax, props)
#      54         self._ax_props = props
#      55         self.open_axes(ax=ax, props=props)
# ---> 56         yield
#      57         self.close_axes(ax=ax)
#      58         self._current_ax = None
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_ax(self, ax)
#     145                 with self.renderer.draw_legend(legend=legend, props=props):
#     146                     if props['visible']:
# --> 147                         self.crawl_legend(ax, legend)
#     148
#     149     def crawl_legend(self, ax, legend):
#
# /Users/Bob/anaconda/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_legend(self, legend, props)
#      64         self._legend_props = props
#      65         self.open_legend(legend=legend, props=props)
# ---> 66         yield
#      67         self.close_legend(legend=legend)
#      68         self._current_legend = None
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_ax(self, ax)
#     145                 with self.renderer.draw_legend(legend=legend, props=props):
#     146                     if props['visible']:
# --> 147                         self.crawl_legend(ax, legend)
#     148
#     149     def crawl_legend(self, ax, legend):
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_legend(self, ax, legend)
#     165                     if not (child is legend.get_children()[-1]
#     166                             and child.get_text() == 'None'):
# --> 167                         self.draw_text(ax, child, force_trans=ax.transAxes)
#     168                 elif isinstance(child, matplotlib.lines.Line2D):
#     169                     self.draw_line(ax, child, force_trans=ax.transAxes)
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mplexporter/exporter.py in draw_text(self, ax, text, force_trans, text_type)
#     209                                     coordinates=coords,
#     210                                     text_type=text_type,
# --> 211                                     style=style, mplobj=text)
#     212
#     213     def draw_patch(self, ax, patch, force_trans=None):
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/renderer.py in draw_text(self, **props)
#     512         """
#     513         self.msg += "    Attempting to draw an mpl text object\n"
# --> 514         if not mpltools.check_corners(props['mplobj'], self.mpl_fig):
#     515             warnings.warn(
#     516                 "Looks like the annotation(s) you are trying \n"
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/mpltools.py in check_corners(inner_obj, outer_obj)
#      40
#      41 def check_corners(inner_obj, outer_obj):
# ---> 42     inner_corners = inner_obj.get_window_extent().corners()
#      43     outer_corners = outer_obj.get_window_extent().corners()
#      44     if inner_corners[0][0] < outer_corners[0][0]:
#
# /Users/Bob/anaconda/lib/python3.5/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     957             self._renderer = renderer
#     958         if self._renderer is None:
# --> 959             raise RuntimeError('Cannot get window extent w/o renderer')
#     960
#     961         bbox, info, descent = self._get_layout(self._renderer)
#
# RuntimeError: Cannot get window extent w/o renderer

# %%
X1 = X_test.iloc[:,1]
R1 = y_pred-y_test

# %% [markdown]
# # Facebook+Awards Model

# %%
y = df2.iloc[:,0]
X = df2.iloc[:,1:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
#  ## 1. Linear Regression (with ridge regularization)

# %%
model = RidgeCV(alphas=(10,25,50,75,100), fit_intercept = True, cv = 10)
fit = model.fit(X_train,y_train)
y_pred = fit.predict(X_test)
score = metrics.r2_score(y_test, y_pred)

res = fit.predict(X)-y
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter(X.iloc[:,1], res,alpha = .3)
plt.plot(X.iloc[:,1],X.iloc[:,1]*0,alpha = .5)
plt.xlabel('first feature variable')
plt.ylabel('residual')
plt.xlim([0.5,7.5])
plt.title('residual plot ' + ' (r-squared = ' + str(score) +')');

plt.subplot(1,2,2)
plt.hist(res,bins = 50)
plt.xlabel('residual')
plt.ylabel('count')
plt.xlim([-6,6])
plt.title('residual histogram');

# %%
X2 = X_test.iloc[:,1]
R2 = y_pred-y_test

# %% [markdown]
# ## 2. Random Forest Regression

# %%
model = RandomForestRegressor(n_estimators = 250, max_features = 7,
                                min_samples_leaf = 4, n_jobs=4)
fit = model.fit(X_train,y_train)
y_pred = fit.predict(X_test)
score = metrics.r2_score(y_test, y_pred)
X1 = X_test.iloc[:,1]
R1 = y_pred-y_test
S1 = score
print(score)
res1 = fit.predict(X)-y
# Out:
# 0.354724374644

# %%
model = GradientBoostingRegressor(n_estimators = 250, learning_rate=0.25)
fit = model.fit(X_train,y_train)
y_pred = fit.predict(X_test)
score = metrics.r2_score(y_test, y_pred)
X2 = X_test.iloc[:,1]
R2 = y_pred-y_test
S2 = score
print(score)
res2 = fit.predict(X)-y
# Out:
# 0.410398460792

# %%
fig = plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter(X.iloc[:,1], res1, c='r', alpha = .3)
plt.scatter(X.iloc[:,1], res2, c='b', alpha = .3)
plt.xlabel('first feature variable')
plt.ylabel('residual')
plt.title('residual plots');
plt.xlim([0,8])
#plt.legend(['Random Forest ' + ' (r-squared = ' + str(S1) +')'
#            ,'Gradient Boosting Regression ' + ' (r-squared = ' + str(S2) +')']);
plt.plot(X.iloc[:,1],X.iloc[:,1]*0,alpha = .5,c='k')

plt.subplot(1,2,2)
plt.hist(res1,bins = 10, color='r', alpha = 0.3)
plt.hist(res2,bins = 10, color='b', alpha = 0.3)
plt.xlabel('residual')
plt.ylabel('count')
plt.xlim([-6,6])
plt.title('residual histogram');
#plt.legend(['Random Forest','Gradient Boosting Regression']);

plotly_fig = py.iplot_mpl(fig)
# Out:
# /Users/Bob/anaconda/lib/python3.5/site-packages/plotly/matplotlylib/renderer.py:516: UserWarning:
#
# Looks like the annotation(s) you are trying
# to draw lies/lay outside the given figure size.
#
# Therefore, the resulting Plotly figure may not be
# large enough to view the full text. To adjust
# the size of the figure, use the 'width' and
# 'height' keys in the Layout object. Alternatively,
# use the Margin object to adjust the figure's margins.

# %% [markdown]
# ## Comparison between Facebook-only model and Facebook+awards model

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter(X1, R1, c='r', alpha = .3)
plt.scatter(X2, R2, c='b', alpha = .3)
plt.xlabel('first feature variable')
plt.ylabel('residual')
plt.xlim([0.5,7.5])
plt.title('residual plots');
plt.legend(['Facebook-only','Facebook+Awards'])
plt.plot(X1,X1*0,alpha = .5)

plt.subplot(1,2,2)
plt.hist(R1,bins = 50, color='r', alpha = 0.3)
plt.hist(R2,bins = 50, color='b', alpha = 0.3)
plt.xlabel('residual')
plt.ylabel('count')
plt.xlim([-6,6])
plt.title('residual histogram');
plt.legend(['Facebook-only','Facebook+Awards']);

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.3'
